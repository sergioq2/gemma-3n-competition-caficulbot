# %% [markdown]
# This code is about clean all the documents and then run the scripts to generate the questions and answers based on gemini model and gpt-4o model using thread to run in parallel

# %%
from PyPDF2 import PdfReader, PdfWriter
import os

# %%
def get_pdf_text(pdf_doc):
    text = []
    pdf_reader = PdfReader(pdf_doc)
    for page_number, page in enumerate(pdf_reader.pages):
        text.append((page_number + 1, page.extract_text()))
    return text

# %%
def process_pd_documents(path):
    for file_index, file in enumerate(os.listdir(path)):
        if file.endswith(".pdf"):
            try:
                pages = get_pdf_text(os.path.join(path, file))
            except:
                continue

# %%
process_pd_documents('documents/focus')

# %%
from PyPDF2 import PdfReader
import os
import pandas as pd
import re
from pathlib import Path

def get_pdf_text(pdf_path):
    try:
        pdf_reader = PdfReader(pdf_path)
        text_pages = []
        
        for page in pdf_reader.pages:
            page_text = page.extract_text()
            if page_text.strip():
                text_pages.append(page_text)
        
        full_text = ' '.join(text_pages)
        return full_text
    
    except Exception as e:
        print(f"Error procesando {pdf_path}: {str(e)}")
        return ""

def clean_text(text):
    if not text or pd.isna(text):
        return ""

    text = str(text)

    replacements = ['\t', '\n', '\r', '#', '-', '__', '@', '/', '`', '>', '<', '{', '}', '!']
    for char in replacements:
        text = text.replace(char, ' ')
    
    text = re.sub(r'[^\w\s.,]', '', text)
    
    text = re.sub(r'\bpdf\b', '', text, flags=re.IGNORECASE)

    text = re.sub(r'\s+', ' ', text)
    
    text = text.strip()
    
    return text

def process_pdf_documents(path):
    if not os.path.exists(path):
        raise FileNotFoundError(f"El directorio {path} no existe")
    
    documents_data = []
    processed_count = 0
    error_count = 0
    
    pdf_files = [f for f in os.listdir(path) if f.lower().endswith('.pdf')]
    
    if not pdf_files:
        print(f"No se encontraron archivos PDF en {path}")
        return pd.DataFrame(columns=['filename', 'text'])
    
    print(f"Procesando {len(pdf_files)} archivos PDF...")
    
    for file in pdf_files:
        file_path = os.path.join(path, file)
        
        try:
            raw_text = get_pdf_text(file_path)
            
            if raw_text.strip():
                clean_text_content = clean_text(raw_text)
                
                if clean_text_content.strip():
                    documents_data.append({
                        'filename': file,
                        'text': clean_text_content
                    })
                    processed_count += 1
                else:
                    print(f"Advertencia: {file} no tiene contenido de texto válido después de la limpieza")
            else:
                print(f"Advertencia: {file} no contiene texto extraíble")
                
        except Exception as e:
            print(f"Error procesando {file}: {str(e)}")
            error_count += 1
            continue
    
    df = pd.DataFrame(documents_data)
    
    print(f"Procesamiento completado:")
    print(f"- Documentos procesados exitosamente: {processed_count}")
    print(f"- Errores: {error_count}")
    print(f"- Total de filas en el DataFrame: {len(df)}")
    
    return df

def get_documents_dataframe(path, save_to_csv=False, output_path=None, name= 'documentos_focus.csv'):
    df = process_pdf_documents(path)
    
    if not df.empty:
        print(f"\nDataFrame creado con {len(df)} documentos")
        print(f"Columnas: {list(df.columns)}")
        print(f"Longitud promedio del texto: {df['text'].str.len().mean():.0f} caracteres")
        
        if save_to_csv:
            if output_path is None:
                output_path = name
            df.to_csv(output_path, index=False, encoding='utf-8')
            print(f"DataFrame guardado en: {output_path}")
    else:
        print("No se pudieron procesar documentos o no se encontraron archivos válidos")
    
    return df

# %%
path_documentos = "documents/focus"
df_documentos_focus = get_documents_dataframe(path_documentos, save_to_csv=True)
print(df_documentos_focus.head())
# Out:
# Procesando 38 archivos PDF...
# Advertencia: Manejo integrado plagas.pdf no contiene texto extraíble
# Advertencia: la sostenibilidad de la caficultura colombiana-- Cadena Gabriel.pdf no contiene texto extraíble
# Advertencia: Portada.pdf no contiene texto extraíble
# Advertencia: Manejo integrado broca parte 1.pdf no contiene texto extraíble
# Advertencia: arc047(04)215-230.pdf no contiene texto extraíble
# Advertencia: 14 Investigaciones en roya cafeto.pdf no contiene texto extraíble
# Procesamiento completado:
# - Documentos procesados exitosamente: 32
# - Errores: 0
# - Total de filas en el DataFrame: 32
#
# DataFrame creado con 32 documentos
# Columnas: ['filename', 'text']
# Longitud promedio del texto: 121792 caracteres
# DataFrame guardado en: documentos_focus.csv
#                       filename  \
# 0                  avt0349.pdf
# 1      yvbravoclmcordobago.pdf
# 2  GuiaMasAgronomia-nov_16.pdf
# 3                   bot036.pdf
# 4                     CAP4.pdf
#
#                                                 text
# 0  349349 Gerencia Técnica Programa de Investigac...
# 1  1 Manej o Agroecológico del Cultivo de C afé C...
# 2  GUÍA Los trabajos suscritos por el personal té...
# 3  Ministro de Hacienda y Crédito Público Ministr...
# 4  El Control Natural de Insectos en el Ecosistem...

# %%
df_documentos_focus.head()
# Out:
#                       filename  \
# 0                  avt0349.pdf
# 1      yvbravoclmcordobago.pdf
# 2  GuiaMasAgronomia-nov_16.pdf
# 3                   bot036.pdf
# 4                     CAP4.pdf
#
#                                                 text
# 0  349349 Gerencia Técnica Programa de Investigac...
# 1  1 Manej o Agroecológico del Cultivo de C afé C...
# 2  GUÍA Los trabajos suscritos por el personal té...
# 3  Ministro de Hacienda y Crédito Público Ministr...
# 4  El Control Natural de Insectos en el Ecosistem...

# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
import os
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(
    model="gpt-4.1-mini-2025-04-14")

# %%
import pandas as pd
from langchain_core.messages import HumanMessage, SystemMessage
import re
from typing import List

def generar_preguntas_para_texto(texto: str, modelo, num_preguntas: int = 10) -> List[str]:
    system_prompt = f"""Eres un ingeniero agrónomo y caficultor colombiano experto en café. 
    Tu tarea es generar exactamente {num_preguntas} preguntas técnicas específicas sobre café basadas ÚNICAMENTE en el contenido del texto proporcionado.
    Note: Ten en cuenta que será preguntas que se usarán para hacer luego un fine tuning a una LLM.
    
    CRITERIOS OBLIGATORIOS para las preguntas:
    - Deben ser preguntas generales, evitar hacer preguntas de la investigación exclusiva como: Abono utilizado en la finca El Agrado durante la investigación?
    - No generes preguntas compuestas, solo una pregunta.
    - Deben ser respondibles EXCLUSIVAMENTE con la información contenida en el texto
    - Enfoque técnico: producción, cultivo, procesamiento, variedades, enfermedades, plagas, calidad, postcosecha, beneficio, etc.
    - Usar terminología técnica precisa del sector cafetero que se maneje en el documento
    - Variar entre aspectos agronómicos, fitosanitarios, de calidad y procesamiento según el contenido
    - Ser específicas al contenido presente en el documento
    
    FORMATO REQUERIDO:
    1. [Primera pregunta técnica]
    2. [Segunda pregunta técnica]
    ...
    {num_preguntas}. [Última pregunta técnica]
    
    IMPORTANTE: Cada pregunta debe tener su respuesta claramente presente en el texto proporcionado."""
    
    messages = [
        SystemMessage(system_prompt),
        HumanMessage(f"Texto a analizar:\n\n{texto}")
    ]
    
    respuesta = modelo.invoke(messages)
    
    if hasattr(respuesta, 'content'):
        contenido = respuesta.content
    else:
        contenido = str(respuesta)
    
    preguntas = extraer_preguntas_numeradas(contenido, num_preguntas)
    
    return preguntas

def extraer_preguntas_numeradas(texto: str, num_esperado: int) -> List[str]:

    patron = r'^\s*\d+[\.\)\-]\s*(.+?)(?=^\s*\d+[\.\)\-]|\Z)'
    preguntas = re.findall(patron, texto, re.MULTILINE | re.DOTALL)
    
    preguntas_limpias = []
    for pregunta in preguntas:
        pregunta_limpia = pregunta.strip().replace('\n', ' ')
        pregunta_limpia = re.sub(r'\s+', ' ', pregunta_limpia)
        if pregunta_limpia:
            preguntas_limpias.append(pregunta_limpia)
    
    if len(preguntas_limpias) != num_esperado:
        lineas = [linea.strip() for linea in texto.split('\n') if linea.strip()]
        preguntas_limpias = []
        for linea in lineas:
            linea_limpia = re.sub(r'^\s*\d+[\.\)\-]\s*', '', linea)
            if linea_limpia and len(linea_limpia) > 10:
                preguntas_limpias.append(linea_limpia)
    
    return preguntas_limpias[:num_esperado]

def procesar_documentos_y_generar_preguntas(df_documentos: pd.DataFrame, modelo, num_preguntas: int = 10) -> pd.DataFrame:
    
    resultados = []
    
    for index, row in df_documentos.iterrows():
        filename = row['filename']
        texto = row['text']
        
        print(f"Procesando archivo: {filename} (fila {index + 1}/{len(df_documentos)})")
        
        try:
            preguntas = generar_preguntas_para_texto(texto, modelo, num_preguntas)
            for pregunta in preguntas:
                resultados.append({
                    'texto': texto,
                    'preguntas': pregunta
                })
            
            print(f"  ✓ Generadas {len(preguntas)} preguntas")
            
        except Exception as e:
            print(f"  ✗ Error procesando {filename}: {str(e)}")
            for _ in range(num_preguntas):
                resultados.append({
                    'texto': texto,
                    'preguntas': f"[Error generando pregunta: {str(e)}]"
                })
    
    df_resultado = pd.DataFrame(resultados)
    
    print(f"\nProcesamiento completado:")
    print(f"- Documentos procesados: {len(df_documentos)}")
    print(f"- Total de preguntas generadas: {len(df_resultado)}")
    print(f"- Preguntas por documento: {num_preguntas}")
    
    return df_resultado

# %%
df_preguntas = procesar_documentos_y_generar_preguntas(df_documentos, model, num_preguntas=10)
# Out:
# Procesando archivo: avt0506.pdf (fila 1/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: avt0411.pdf (fila 2/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: avt0536.pdf (fila 3/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: avt0349.pdf (fila 4/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: avt0388.pdf (fila 5/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: avt0370.pdf (fila 6/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: avt0398.pdf (fila 7/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: avt0569.pdf (fila 8/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: avt0477.pdf (fila 9/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: avt0422.pdf (fila 10/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: avt0492.pdf (fila 11/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: arc057(03)232-242.pdf (fila 12/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: avt0358.pdf (fila 13/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: avt0403.pdf (fila 14/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: avt0530.pdf (fila 15/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: avt0354.pdf (fila 16/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: avt0395.pdf (fila 17/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: avt0336.pdf (fila 18/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: avt0335.pdf (fila 19/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: avt0436.pdf (fila 20/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: AT_563.pdf (fila 21/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: avt0419.pdf (fila 22/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: avt0539.pdf (fila 23/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: avt0502.pdf (fila 24/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: avt0426.pdf (fila 25/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: avt0456.pdf (fila 26/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: avt0346.pdf (fila 27/187)
#   ✓ Generadas 10 preguntas
# Procesando archivo: avt
lixiviación, las cuales son más evidentes en épocas de mayor pluviosidad, tal como ocurre durante un evento La Niña. Con el objetivo de evaluar el efecto del fraccionamiento de la fertilización requerida por año en la producción del café, se llevó a cabo una investigación en plantaciones de Variedad Castillo a libre exposición solar, ubicadas en cinco localidades de la zona cafetera, con suelos de textura franco arenosa y franco arcillo arenosa, así como diferentes contenidos de materia orgánica y condiciones de pluviosidad Tabla 1. Evaluación del efecto del fraccionamiento Durante la fase de crecimiento vegetativo los cafetales recibieron una fertilización de acuerdo con los resultados del análisis de suelos Sadeghian, 2008, así como el manejo integrado de arvenses, plagas y enfermedades de acuerdo con las recomendaciones de Cenicafé. A los 18 meses de edad, se analizó una nueva muestra con el fin de programar la fertilización de la fase reproductiva, en la cual se aplicaron cuatro tratamientos, consistentes en el suministro de la fertilización requerida por año en cuatro épocas oportunidades, así Tratamiento 1 fraccionada cada seis meses 50 por aplicación. Tratamiento 2 fraccionada cada cuatro meses 33 por aplicación. Tratamiento 3 fraccionada cada tres meses 25 por aplicación. Tratamiento 4 fraccionada cada dos meses 16 por aplicación.Manizales, Caldas, Colombia Tel. 6 8500707 A.A. 2427 Manizales www.cenicafe.orgISSN 0120 0178 ISSN 2145 3691 En línea Los trabajos suscritos por el personal técnico del Centro Nacional de Investigaciones de Café son parte de las investigaciones realizadas por la Federación Nacional de Cafeteros de Colombia. Sin embargo, tanto en este caso como en el de personas no pertenecientes a este Centro, las ideas emitidas por los autores son de su exclusiva responsabilidad y no expresan necesariamente las opiniones de la Entidad.Edición Sandra Milena Marín López Fotografías Archivo Cenicafé Diagramación Luz Adriana Álvarez Monsalve Imprenta Autores Hernán González Osorio Investigador Científico I https orcid.org 0000 0001 5716 2172 Siavosh Sadeghian Khalajabadi Investigador Científico III https orcid.org 0000 0003 1266 0885 Disciplina de Suelos Centro Nacional de Investigaciones de Café Ceni ...

# %%
df_preguntas['preguntas'][0]
# Out:
# '¿Qué factores determinan la eficiencia de la fertilización en el cultivo del café según el documento?'

# %%
df_preguntas['preguntas'][1]
# Out:
# '¿Cuál es la recomendación tradicional sobre la frecuencia anual de fertilización en cafetales en producción en Colombia?'

# %%
df_preguntas['preguntas'][2]
# Out:
# '¿Cómo se realizó el fraccionamiento de la fertilización en los cuatro tratamientos establecidos durante la fase reproductiva según el estudio?'

# %%
df_preguntas['preguntas'][3]
# Out:
# '¿Qué tipo de fertilizantes se utilizaron para suplir los requerimientos de nitrógeno, fósforo, potasio y magnesio en las parcelas estudiadas?'

# %%
df_preguntas['preguntas'][4]
# Out:
# '¿Cuál fue el criterio clave para seleccionar el momento de aplicación de fertilizantes en relación con la humedad del suelo?'

# %%
df_preguntas['preguntas'][1000]
# Out:
# '¿Cuáles son las dos formas principales de azufre presentes en los suelos de la zona cafetera colombiana?'

# %%
path_documentos = "documents/revistas"
df_documentos = get_documents_dataframe(path_documentos, save_to_csv=True, name='documentos_revistas_preguntas.csv')
print(df_documentos.head())
# Out:
# Procesando 200 archivos PDF...
# Error procesando documents/revistas/1.Aplicacion.pdf: PyCryptodome is required for AES algorithm
# Advertencia: 1.Aplicacion.pdf no contiene texto extraíble
# Error procesando documents/revistas/arc061(01)055-066.pdf: PyCryptodome is required for AES algorithm
# Advertencia: arc061(01)055-066.pdf no contiene texto extraíble
# Error procesando documents/revistas/3.Dispositivo.pdf: PyCryptodome is required for AES algorithm
# Advertencia: 3.Dispositivo.pdf no contiene texto extraíble
# Error procesando documents/revistas/2.Descripcion.pdf: PyCryptodome is required for AES algorithm
# Advertencia: 2.Descripcion.pdf no contiene texto extraíble
# Error procesando documents/revistas/arc069(01)055-067.pdf: PyCryptodome is required for AES algorithm
# Advertencia: arc069(01)055-067.pdf no contiene texto extraíble
# Error procesando documents/revistas/Revista69(1)-Web1.pdf: PyCryptodome is required for AES algorithm
# Advertencia: Revista69(1)-Web1.pdf no contiene texto extraíble
# Error procesando documents/revistas/Revista68.pdf: PyCryptodome is required for AES algorithm
# Advertencia: Revista68.pdf no contiene texto extraíble
# Error procesando documents/revistas/5.Epidemiología.pdf: PyCryptodome is required for AES algorithm
# Advertencia: 5.Epidemiología.pdf no contiene texto extraíble
# Error procesando documents/revistas/6.Relacion.pdf: PyCryptodome is required for AES algorithm
# Advertencia: 6.Relacion.pdf no contiene texto extraíble
# Error procesando documents/revistas/Revista_Cenicafé_67(2).pdf: PyCryptodome is required for AES algorithm
# Advertencia: Revista_Cenicafé_67(2).pdf no contiene texto extraíble
# Error procesando documents/revistas/RevistaCenicafe67-1.pdf: PyCryptodome is required for AES algorithm
# Advertencia: RevistaCenicafe67-1.pdf no contiene texto extraíble
# Error procesando documents/revistas/7.Evaluacion.pdf: PyCryptodome is required for AES algorithm
# Advertencia: 7.Evaluacion.pdf no contiene texto extraíble
# Error procesando documents/revistas/6.Evaluación.pdf: PyCryptodome is required for AES algorithm
# Advertencia: 6.Evaluación.pdf no contiene texto extraíble
# Error procesando documents/revistas/arc061(01)046-054.pdf: PyCryptodome is required for AES algorithm
# Advertencia: arc061(01)046-054.pdf no contiene texto extraíble
# Error procesando documents/revistas/4.ElCiclo.pdf: PyCryptodome is required for AES algorithm
# Advertencia: 4.ElCiclo.pdf no contiene texto extraíble
# Error procesando documents/revistas/5.Estimacion.pdf: PyCryptodome is required for AES algorithm
# Advertencia: 5.Estimacion.pdf no contiene texto extraíble
# Error procesando documents/revistas/arc069(01)068-082.pdf: PyCryptodome is required for AES algorithm
# Advertencia: arc069(01)068-082.pdf no contiene texto extraíble
# Error procesando documents/revistas/Revista68-1.pdf: PyCryptodome is required for AES algorithm
# Advertencia: Revista68-1.pdf no contiene texto extraíble
# Error procesando documents/revistas/arc061(01)067-089.pdf: PyCryptodome is required for AES algorithm
# Advertencia: arc061(01)067-089.pdf no contiene texto extraíble
# Error procesando documents/revistas/arc069(01)091-111.pdf: PyCryptodome is required for AES algorithm
# Advertencia: arc069(01)091-111.pdf no contiene texto extraíble
# Error procesando documents/revistas/arc069(01)083-090.pdf: PyCryptodome is required for AES algorithm
# Advertencia: arc069(01)083-090.pdf no contiene texto extraíble
# Error procesando documents/revistas/2.Diagnostico.pdf: PyCryptodome is required for AES algorithm
# Advertencia: 2.Diagnostico.pdf no contiene texto extraíble
# Error procesando documents/revistas/arc061(01)035-045.pdf: PyCryptodome is required for AES algorithm
# Advertencia: arc061(01)035-045.pdf no contiene texto extraíble
# Error procesando documents/revistas/4.Efecto (1).pdf: PyCryptodome is required for AES algorithm
# Advertencia: 4.Efecto (1).pdf no contiene texto extraíble
# Error procesando documents/revistas/arc061(01)028-034.pdf: PyCryptodome is required for AES algorithm
# Advertencia: arc061(01)028-034.pdf no contiene texto extraíble
# Error procesando documents/revistas/1.Aplicacion (1).pdf: PyCryptodome is required for AES algorithm
# Advertencia: 1.Aplicacion (1).pdf no contiene texto extraíble
# Error procesando documents/revistas/4.Efecto.pdf: PyCryptodome is required for AES algorithm
# Advertencia: 4.Efecto.pdf no contiene texto extraíble
# Error procesando documents/revistas/arc061(01)007-027.pdf: PyCryptodome is required for AES algorithm
# Advertencia: arc061(01)007-027.pdf no contiene texto extraíble
# Error procesando documents/revistas/7.Zonificacion.pdf: PyCryptodome is required for AES algorithm
# Advertencia: 7.Zonificacion.pdf no contiene texto extraíble
# Error procesando documents/revistas/RevistaCenicafe66-2.pdf: PyCryptodome is required for AES algorithm
# Advertencia: RevistaCenicafe66-2.pdf no contiene texto extraíble
# Error procesando documents/revistas/3.Densidad.pdf: PyCryptodome is required for AES algorithm
# Advertencia: 3.Densidad.pdf no contiene texto extraíble
# Procesamiento completado:
# - Documentos procesados exitosamente: 169
# - Errores: 0
# - Total de filas en el DataFrame: 169
#
# DataFrame creado con 169 documentos
# Columnas: ['filename', 'text']
# Longitud promedio del texto: 69892 caracteres
# DataFrame guardado en: documentos_revistas_preguntas.csv
#                           filename  \
# 0  Articulo_AspectosBiologicos.pdf
# 1            arc061(03)241-251.pdf
# 2                  5.Hemiptera.pdf
# 3            arc070(02)091-097.pdf
# 4            arc069(01)032-039.pdf
#
#                                                 text
# 0  Cenicafé, 742 20237Giraldo Jaramillo, M. 2023....
# 1  Cenicafé, 613241 251. 2010 241EVALUACIÓN DE UN...
# 2  Cenicafé, 67173 80. 201673HEMIPTERA COCCOIDEA ...
# 3  Cenicafé, 70291 97. 201991LÓPEZ F., F. LAITON ...
# 4  Cenicafé, 69132 39. 201832GIRALDO J., M. Efect...

# %%
df_documentos.head()
# Out:
#                           filename  \
# 0  Articulo_AspectosBiologicos.pdf
# 1            arc061(03)241-251.pdf
# 2                  5.Hemiptera.pdf
# 3            arc070(02)091-097.pdf
# 4            arc069(01)032-039.pdf
#
#                                                 text
# 0  Cenicafé, 742 20237Giraldo Jaramillo, M. 2023....
# 1  Cenicafé, 613241 251. 2010 241EVALUACIÓN DE UN...
# 2  Cenicafé, 67173 80. 201673HEMIPTERA COCCOIDEA ...
# 3  Cenicafé, 70291 97. 201991LÓPEZ F., F. LAITON ...
# 4  Cenicafé, 69132 39. 201832GIRALDO J., M. Efect...

# %%
df_documentos['text'][0]
# Out:
df_documentos['longitud'] = df_documentos['text'].str.split().str.len()

# %%
df_documentos.head()
# Out:
#                           filename  \
# 0  Articulo_AspectosBiologicos.pdf
# 1            arc061(03)241-251.pdf
# 2                  5.Hemiptera.pdf
# 3            arc070(02)091-097.pdf
# 4            arc069(01)032-039.pdf
#
#                                                 text  longitud
# 0  Cenicafé, 742 20237Giraldo Jaramillo, M. 2023....      4248
# 1  Cenicafé, 613241 251. 2010 241EVALUACIÓN DE UN...      4682
# 2  Cenicafé, 67173 80. 201673HEMIPTERA COCCOIDEA ...      3800
# 3  Cenicafé, 70291 97. 201991LÓPEZ F., F. LAITON ...      4693
# 4  Cenicafé, 69132 39. 201832GIRALDO J., M. Efect...      3731

# %%
import pandas as pd
from langchain_core.messages import HumanMessage, SystemMessage
import re
from typing import List

def determinar_num_preguntas(longitud: int) -> int:
    """
    Determina el número de preguntas a generar basado en la longitud del texto
    """
    if longitud < 5000:
        return 8
    elif 5001 <= longitud <= 10000:
        return 10
    elif 10001 <= longitud <= 15000:
        return 15
    elif 15001 <= longitud <= 20000:
        return 15
    elif 20001 <= longitud <= 30000:
        return 20
    elif 30001 <= longitud <= 40000:
        return 25
    else:  # mayor a 40000
        return 30

def generar_preguntas_para_texto(texto: str, modelo, num_preguntas: int = 10) -> List[str]:
    system_prompt = f"""Eres un ingeniero agrónomo y caficultor colombiano experto en café. 
    Tu tarea es generar exactamente {num_preguntas} preguntas técnicas específicas sobre café basadas ÚNICAMENTE en el contenido del texto proporcionado.
    Note: Ten en cuenta que será preguntas que se usarán para hacer luego un fine tuning a una LLM.
    
    CRITERIOS OBLIGATORIOS para las preguntas:
    - Enfocate mucho en control de enfermedades, plagas, pràcticas agrìcolas, manejo de cultivo
    - Deben ser preguntas generales, evitar hacer preguntas de la investigación exclusiva como: Abono utilizado en la finca El Agrado durante la investigación?
    - No generes preguntas compuestas, solo una pregunta.
    - Deben ser respondibles EXCLUSIVAMENTE con la información contenida en el texto
    - Enfoque técnico: producción, cultivo, procesamiento, variedades, enfermedades, plagas, calidad, postcosecha, beneficio, etc.
    - Usar terminología técnica precisa del sector cafetero que se maneje en el documento
    - Variar entre aspectos agronómicos, fitosanitarios, de calidad y procesamiento según el contenido
    - Ser específicas al contenido presente en el documento
    
    FORMATO REQUERIDO:
    1. [Primera pregunta técnica]
    2. [Segunda pregunta técnica]
    ...
    {num_preguntas}. [Última pregunta técnica]
    
    IMPORTANTE: Cada pregunta debe tener su respuesta claramente presente en el texto proporcionado."""
    
    messages = [
        SystemMessage(system_prompt),
        HumanMessage(f"Texto a analizar:\n\n{texto}")
    ]
    
    respuesta = modelo.invoke(messages)
    
    if hasattr(respuesta, 'content'):
        contenido = respuesta.content
    else:
        contenido = str(respuesta)
    
    preguntas = extraer_preguntas_numeradas(contenido, num_preguntas)
    
    return preguntas

def extraer_preguntas_numeradas(texto: str, num_esperado: int) -> List[str]:

    patron = r'^\s*\d+[\.\)\-]\s*(.+?)(?=^\s*\d+[\.\)\-]|\Z)'
    preguntas = re.findall(patron, texto, re.MULTILINE | re.DOTALL)
    
    preguntas_limpias = []
    for pregunta in preguntas:
        pregunta_limpia = pregunta.strip().replace('\n', ' ')
        pregunta_limpia = re.sub(r'\s+', ' ', pregunta_limpia)
        if pregunta_limpia:
            preguntas_limpias.append(pregunta_limpia)
    
    if len(preguntas_limpias) != num_esperado:
        lineas = [linea.strip() for linea in texto.split('\n') if linea.strip()]
        preguntas_limpias = []
        for linea in lineas:
            linea_limpia = re.sub(r'^\s*\d+[\.\)\-]\s*', '', linea)
            if linea_limpia and len(linea_limpia) > 10:
                preguntas_limpias.append(linea_limpia)
    
    return preguntas_limpias[:num_esperado]

def procesar_documentos_y_generar_preguntas(df_documentos: pd.DataFrame, modelo) -> pd.DataFrame:
    if 'longitud' not in df_documentos.columns:
        raise ValueError("El DataFrame debe tener una columna 'longitud' con el número de palabras")
    
    resultados = []
    
    for index, row in df_documentos.iterrows():
        filename = row['filename']
        texto = row['text']
        longitud = row['longitud']
        
        num_preguntas = determinar_num_preguntas(longitud)
        
        print(f"Procesando archivo: {filename} (fila {index + 1}/{len(df_documentos)})")
        print(f"  Longitud: {longitud} palabras → {num_preguntas} preguntas")
        
        try:
            preguntas = generar_preguntas_para_texto(texto, modelo, num_preguntas)
            for pregunta in preguntas:
                resultados.append({
                    'texto': texto,
                    'preguntas': pregunta,
                    'longitud_original': longitud,
                    'num_preguntas_generadas': num_preguntas
                })
            
            print(f"  ✓ Generadas {len(preguntas)} preguntas")
            
        except Exception as e:
            print(f"  ✗ Error procesando {filename}: {str(e)}")
            for _ in range(num_preguntas):
                resultados.append({
                    'texto': texto,
                    'preguntas': f"[Error generando pregunta: {str(e)}]",
                    'longitud_original': longitud,
                    'num_preguntas_generadas': num_preguntas
                })
    
    df_resultado = pd.DataFrame(resultados)
    
    print(f"\nProcesamiento completado:")
    print(f"- Documentos procesados: {len(df_documentos)}")
    print(f"- Total de preguntas generadas: {len(df_resultado)}")
    
    df_stats = df_documentos.copy()
    df_stats['num_preguntas'] = df_stats['longitud'].apply(determinar_num_preguntas)
    
    print(f"\nDistribución de preguntas por longitud:")
    stats_summary = df_stats.groupby('num_preguntas').agg({
        'longitud': ['count', 'mean', 'min', 'max']
    }).round(2)
    print(stats_summary)
    
    return df_resultado

# %%
df_preguntas_revistas = procesar_documentos_y_generar_preguntas(df_documentos, model)
# Out:
# Procesando archivo: Articulo_AspectosBiologicos.pdf (fila 1/169)
#   Longitud: 4248 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: arc061(03)241-251.pdf (fila 2/169)
#   Longitud: 4682 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: 5.Hemiptera.pdf (fila 3/169)
#   Longitud: 3800 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: arc070(02)091-097.pdf (fila 4/169)
#   Longitud: 4693 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: arc069(01)032-039.pdf (fila 5/169)
#   Longitud: 3731 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: Rev._62(1)._art_1._Conservacion_de_suelos.pdf (fila 6/169)
#   Longitud: 4416 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: arc71(2)007-020.pdf (fila 7/169)
#   Longitud: 5784 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: arc072(02)e72202.pdf (fila 8/169)
#   Longitud: 5006 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: arc069(01)007-015.pdf (fila 9/169)
#   Longitud: 4255 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: arc072(02)e72201.pdf (fila 10/169)
#   Longitud: 5871 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo:
palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: arc060(03)253-268.pdf (fila 89/169)
#   Longitud: 6293 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: Articulo_Analisis.pdf (fila 90/169)
#   Longitud: 7274 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: Revista62_2.pdf (fila 91/169)
#   Longitud: 62215 palabras → 30 preguntas
#   ✓ Generadas 30 preguntas
# Procesando archivo: Revista72(1).pdf (fila 92/169)
#   Longitud: 48010 palabras → 30 preguntas
#   ✓ Generadas 30 preguntas
# Procesando archivo: arc070(02)019-029.pdf (fila 93/169)
#   Longitud: 5647 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: 2.pdf (fila 94/169)
#   Longitud: 8029 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: Revista74(2)Web.pdf (fila 95/169)
#   Longitud: 39285 palabras → 25 preguntas
#   ✓ Generadas 25 preguntas
# Procesando archivo: 3-Estudio_(1).pdf (fila 96/169)
#   Longitud: 6855 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: Revista63_2.pdf (fila 97/169)
#   Longitud: 56153 palabras → 30 preguntas
#   ✓ Generadas 30 preguntas
# Procesando archivo: arc072(02)e72204.pdf (fila 98/169)
#   Longitud: 5049 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: Rev._62(1)._art_7._Propiedades_fisicas_Andisol.pdf (fila 99/169)
#   Longitud: 6020 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: 4.LasMoscas.pdf (fila 100/169)
#   Longitud: 5328 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: e72103.pdf (fila 101/169)
#   Longitud: 6114 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: arc061(04)327-343.pdf (fila 102/169)
#   Longitud: 8215 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: arc072(02)e72206.pdf (fila 103/169)
#   Longitud: 5672 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: Articulo_Chisas.pdf (fila 104/169)
#   Longitud: 8066 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: Rev._62(1)._art_4._Cochinillas.pdf (fila 105/169)
#   Longitud: 3451 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: arc060(04)352-373.pdf (fila 106/169)
#   Longitud: 5189 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: arc069(02)007-016.pdf (fila 107/169)
#   Longitud: 4652 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: Articulo_JulioQuiroga.pdf (fila 108/169)
#   Longitud: 16365 palabras → 15 preguntas
#   ✓ Generadas 15 preguntas
# Procesando archivo: arc060(03)269-281.pdf (fila 109/169)
#   Longitud: 4790 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: 2.Evaluacion.pdf (fila 110/169)
#   Longitud: 6653 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: Revista63_1.pdf (fila 111/169)
#   Longitud: 64042 palabras → 30 preguntas
#   ✓ Generadas 30 preguntas
# Procesando archivo: arc061(04)281-296.pdf (fila 112/169)
#   Longitud: 6259 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: arc060(04)324-350.pdf (fila 113/169)
#   Longitud: 12614 palabras → 15 preguntas
#   ✓ Generadas 15 preguntas
# Procesando archivo: arc061(04)315-326.pdf (fila 114/169)
#   Longitud: 5370 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: Articulo-Validacion.pdf (fila 115/169)
#   Longitud: 4943 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: 5.Micronutrientes.pdf (fila 116/169)
#   Longitud: 6803 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: 3.Densidad_de_siembra_del_café_Variedad_Castillo.pdf (fila 117/169)
#   Longitud: 3726 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: 6.Propiedades_61-75.pdf (fila 118/169)
#   Longitud: 6474 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: arc070(01)030-043.pdf (fila 119/169)
#   Longitud: 5368 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: arc071(02)066-072.pdf (fila 120/169)
#   Longitud: 3042 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: Rev._62(1)._art_7._Propiedades_fisicas_Andisol (1).pdf (fila 121/169)
#   Longitud: 6020 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: 73201.pdf (fila 122/169)
#   Longitud: 4984 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: 73205.pdf (fila 123/169)
#   Longitud: 5297 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: Revista73(2)Web_(1).pdf (fila 124/169)
#   Longitud: 45976 palabras → 30 preguntas
#   ✓ Generadas 30 preguntas
# Procesando archivo: Revista71(2).pdf (fila 125/169)
#   Longitud: 60984 palabras → 30 preguntas
#   ✓ Generadas 30 preguntas
# Procesando archivo: Revista65_2.pdf (fila 126/169)
#   Longitud: 32193 palabras → 25 preguntas
#   ✓ Generadas 25 preguntas
# Procesando archivo: 5.Manejo.pdf (fila 127/169)
#   Longitud: 5897 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: arc071(02)118-123.pdf (fila 128/169)
#   Longitud: 2460 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: arc070(01)007-017.pdf (fila 129/169)
#   Longitud: 5258 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: arc061(03)262-271.pdf (fila 130/169)
#   Longitud: 4138 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: arc060(04)313-323.pdf (fila 131/169)
#   Longitud: 4824 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: 73203.pdf (fila 132/169)
#   Longitud: 4012 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: Articulo_Influencia.pdf (fila 133/169)
#   Longitud: 6588 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: Articulo_Inocuidad.pdf (fila 134/169)
#   Longitud: 6061 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: 4-Fertilizacion.pdf (fila 135/169)
#   Longitud: 2693 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: arc71(02)021-038.pdf (fila 136/169)
#   Longitud: 7126 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: 6.Respuesta.pdf (fila 137/169)
#   Longitud: 5183 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: 2.Analisis.pdf (fila 138/169)
#   Longitud: 11291 palabras → 15 preguntas
#   ✓ Generadas 15 preguntas
# Procesando archivo: 1.Acumulacion.pdf (fila 139/169)
#   Longitud: 5006 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: 7.pdf (fila 140/169)
#   Longitud: 3612 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: Revista62_11.pdf (fila 141/169)
#   Longitud: 55467 palabras → 30 preguntas
#   ✓ Generadas 30 preguntas
# Procesando archivo: Revista_75-2.pdf (fila 142/169)
#   Longitud: 34278 palabras → 25 preguntas
#   ✓ Generadas 25 preguntas
# Procesando archivo: arc071(02)124-142.pdf (fila 143/169)
#   Longitud: 7758 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: arc061(03)195-2052.pdf (fila 144/169)
#   Longitud: 4240 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: Revista65_1.pdf (fila 145/169)
#   Longitud: 25900 palabras → 20 preguntas
#   ✓ Generadas 20 preguntas
# Procesando archivo: arc061(03)252-261.pdf (fila 146/169)
#   Longitud: 4945 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: arc070(02)081-090.pdf (fila 147/169)
#   Longitud: 4419 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: 2.Barrenador.pdf (fila 148/169)
#   Longitud: 3362 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: Revista_76-1.pdf (fila 149/169)
#   Longitud: 30799 palabras → 25 preguntas
#   ✓ Generadas 25 preguntas
# Procesando archivo: arc070(02)007-018.pdf (fila 150/169)
#   Longitud: 5649 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: arc061(02)99-107.pdf (fila 151/169)
#   Longitud: 4317 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: 8.pdf (fila 152/169)
#   Longitud: 5001 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: 8-Evaluacion.pdf (fila 153/169)
#   Longitud: 5552 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: arc070(01)065-080.pdf (fila 154/169)
#   Longitud: 6637 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: Rev._62(1)._art_9._Sostenibilidad_ambiental.pdf (fila 155/169)
#   Longitud: 9253 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: Articulo_Conductancia.pdf (fila 156/169)
#   Longitud: 5521 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: 1-CorreccionAcidez_(1).pdf (fila 157/169)
#   Longitud: 6054 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: arc061(02)132-158.pdf (fila 158/169)
#   Longitud: 10341 palabras → 15 preguntas
#   ✓ Generadas 15 preguntas
# Procesando archivo: e72101.pdf (fila 159/169)
#   Longitud: 7286 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: arc060(03)239-252.pdf (fila 160/169)
#   Longitud: 5647 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: 3.Erosividad_25-31.pdf (fila 161/169)
#   Longitud: 3134 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: Articulo_Determinacio.pdf (fila 162/169)
#   Longitud: 7573 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: 73206.pdf (fila 163/169)
#   Longitud: 6736 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: 3.Factores.pdf (fila 164/169)
#   Longitud: 13323 palabras → 15 preguntas
#   ✓ Generadas 15 preguntas
# Procesando archivo: arc060(01)072-085.pdf (fila 165/169)
#   Longitud: 6171 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: Revista72(2)Web.pdf (fila 166/169)
#   Longitud: 60291 palabras → 30 preguntas
#   ✓ Generadas 30 preguntas
# Procesando archivo: 6.pdf (fila 167/169)
#   Longitud: 5700 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: Revista69(2)-Web1.pdf (fila 168/169)
#   Longitud: 27584 palabras → 20 preguntas
#   ✓ Generadas 20 preguntas
# Procesando archivo: arc072(02)e72207.pdf (fila 169/169)
#   Longitud: 4210 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
#
# Procesamiento completado:
# - Documentos procesados: 169
# - Total de preguntas generadas: 2042
#
# Distribución de preguntas por longitud:
#               longitud
#                  count      mean    min    max
# num_preguntas
# 8                   44   4120.80   2460   4984
# 10                  95   6545.93   5001   9921
# 15                   7  12577.71  10341  16365
# 20                   2  26742.00  25900  27584
# 25                   7  34420.57  30799  39285
# 30                  14  51700.64  40249  64042

# %%
df_preguntas_revistas.shape
# Out:
# (2042, 4)

# %%
path_documentos = "documents/libros"
df_documentos_libros = get_documents_dataframe(path_documentos, save_to_csv=True, name='documentos_libros_preguntas.csv')
print(df_documentos_libros.head())
# Out:
# Procesando 38 archivos PDF...
# Advertencia: Portada.pdf no contiene texto extraíble
# Advertencia: Manejo integrado broca parte 1.pdf no contiene texto extraíble
# Advertencia: 32 Resistencia genética a roya cafeto.pdf no contiene texto extraíble
# Advertencia: Manejo integrado enfermedades.pdf no contiene texto extraíble
# Error procesando documents/libros/libroClima.pdf: PyCryptodome is required for AES algorithm
# Advertencia: libroClima.pdf no contiene texto extraíble
# Error procesando documents/libros/lib37751.pdf: PyCryptodome is required for AES algorithm
# Advertencia: lib37751.pdf no contiene texto extraíble
# Procesamiento completado:
# - Documentos procesados exitosamente: 32
# - Errores: 0
# - Total de filas en el DataFrame: 32
#
# DataFrame creado con 32 documentos
# Columnas: ['filename', 'text']
# Longitud promedio del texto: 300066 caracteres
# DataFrame guardado en: documentos_libros_preguntas.csv
#                       filename  \
# 0                  Arboles.pdf
# 1                 LIBRORED.pdf
# 2  memorias_seminarios2020.pdf
# 3            LibroSuelos_w.pdf
# 4  GuiaMasAgronomia-nov_16.pdf
#
#                                                 text
# 0  1 2 Créditos Edición de textos Sandr a Milena ...
# 1  Comité Nacional Ministro de Hacienda y Crédito...
# 2  Seminario CientíficoMemorias Cenicafé 202071ºC...
# 3  del café Siavosh Sadeghian Khalajabadidel suel...
# 4  GUÍA Los trabajos suscritos por el personal té...

# %%
df_documentos_libros.shape
# Out:
# (32, 2)

# %%
df_documentos_focus['longitud'] = df_documentos_focus['text'].str.split().str.len()

# %%
df_preguntas_libros = procesar_documentos_y_generar_preguntas(df_documentos_focus, model)
# Out:
# Procesando archivo: avt0349.pdf (fila 1/32)
#   Longitud: 7009 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: yvbravoclmcordobago.pdf (fila 2/32)
#   Longitud: 23894 palabras → 20 preguntas
#   ✓ Generadas 20 preguntas
# Procesando archivo: GuiaMasAgronomia-nov_16.pdf (fila 3/32)
#   Longitud: 32433 palabras → 25 preguntas
#   ✓ Generadas 25 preguntas
# Procesando archivo: bot036.pdf (fila 4/32)
#   Longitud: 16038 palabras → 15 preguntas
#   ✓ Generadas 15 preguntas
# Procesando archivo: CAP4.pdf (fila 5/32)
#   Longitud: 19047 palabras → 15 preguntas
#   ✓ Generadas 15 preguntas
# Procesando archivo: Bustillo-2007-Biocontrol-of-coffee-berry-borer.pdf (fila 6/32)
#   Longitud: 3816 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: avt0478.pdf (fila 7/32)
#   Longitud: 3721 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: Agentic architecture.docx.pdf (fila 8/32)
#   Longitud: 7777 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: broca_cafe.pdf (fila 9/32)
#   Longitud: 4047 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: LibroArvenses-Web.pdf (fila 10/32)
#   Longitud: 58694 palabras → 30 preguntas
#   ✓ Generadas 30 preguntas
# Procesando archivo: Seccion5Labroca.Seccion6Plagascuarentenarias.Seccion7Perspectivas.pdf (fila 11/32)
#   Longitud: 39065 palabras → 25 preguntas
#   ✓ Generadas 25 preguntas
# Procesando archivo: cenbook-0026_24.pdf (fila 12/32)
#   Longitud: 20495 palabras → 20 preguntas
#   ✓ Generadas 20 preguntas
# Procesando archivo: GuiaMasAgronomia-Rebajada.pdf (fila 13/32)
#   Longitud: 20406 palabras → 20 preguntas
#   ✓ Generadas 20 preguntas
# Procesando archivo: Manual-Cafe-Robusta.pdf (fila 14/32)
#   Longitud: 17738 palabras → 15 preguntas
#   ✓ Generadas 15 preguntas
# Procesando archivo: 15Anexos.pdf (fila 15/32)
#   Longitud: 7450 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: 53._principales_enfermedades_del_cultivo_de_cafe_05-21.pdf (fila 16/32)
#   Longitud: 1276 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: Boletin-Broca-Abril-2023.pdf (fila 17/32)
#   Longitud: 924 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: boletinplagasenfermedades01deseptiembre.pdf (fila 18/32)
#   Longitud: 734 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: Guía vigilancia - VF.pdf (fila 19/32)
#   Longitud: 11349 palabras → 15 preguntas
#   ✓ Generadas 15 preguntas
# Procesando archivo: cartilla_14_manejo_integrado_de_la_broca.pdf (fila 20/32)
#   Longitud: 1758 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: cenbook-0026_23.pdf (fila 21/32)
#   Longitud: 18460 palabras → 15 preguntas
#   ✓ Generadas 15 preguntas
# Procesando archivo: SEPARATAROYA.pdf (fila 22/32)
#   Longitud: 1762 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: 179914617007.pdf (fila 23/32)
#   Longitud: 6082 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: 17-situacion-roya.pdf (fila 24/32)
#   Longitud: 5156 palabras → 10 preguntas
#   ✓ Generadas 10 preguntas
# Procesando archivo: bot032.pdf (fila 25/32)
#   Longitud: 17782 palabras → 15 preguntas
#   ✓ Generadas 15 preguntas
# Procesando archivo: Ficha Técnica de Mancha de hierro.pdf (fila 26/32)
#   Longitud: 1607 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: Perez-2006-Coffee-berry-borer.pdf (fila 27/32)
#   Longitud: 96098 palabras → 30 preguntas
#   ✓ Generadas 30 preguntas
# Procesando archivo: sistemas_de_produccion.pdf (fila 28/32)
#   Longitud: 155211 palabras → 30 preguntas
#   ✓ Generadas 30 preguntas
# Procesando archivo: Boletin-Conociendo-Broca-Diciembre-2024.pdf (fila 29/32)
#   Longitud: 1733 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: cenbook-0026_22.pdf (fila 30/32)
#   Longitud: 20214 palabras → 20 preguntas
#   ✓ Generadas 20 preguntas
# Procesando archivo: Manejo Integrado de la Broca-Promecafe.pdf (fila 31/32)
#   Longitud: 1605 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
# Procesando archivo: avt0480.pdf (fila 32/32)
#   Longitud: 2554 palabras → 8 preguntas
#   ✓ Generadas 8 preguntas
#
# Procesamiento completado:
# - Documentos procesados: 32
# - Total de preguntas generadas: 456
#
# Distribución de preguntas por longitud:
#               longitud
#                  count       mean    min     max
# num_preguntas
# 8                   12    2128.08    734    4047
# 10                   5    6694.80   5156    7777
# 15                   6   16735.67  11349   19047
# 20                   4   21252.25  20214   23894
# 25                   2   35749.00  32433   39065
# 30                   3  103334.33  58694  155211

# %%
df_preguntas.head()
# Out:
#                                                texto  \
# 0  Fraccionamiento de la fertilización en el cult...
# 1  Fraccionamiento de la fertilización en el cult...
# 2  Fraccionamiento de la fertilización en el cult...
# 3  Fraccionamiento de la fertilización en el cult...
# 4  Fraccionamiento de la fertilización en el cult...
#
#                                            preguntas
# 0  ¿Cuál fue la variedad de café utilizada en la ...
# 1  ¿Qué tipos de fertilizantes se emplearon para ...
# 2  ¿Cuáles fueron las texturas predominantes de l...
# 3  ¿En qué momento se programó la fertilización p...
# 4  ¿Cuáles fueron las frecuencias de aplicación d...

# %%
df_preguntas_libros.head()
# Out:
#                                                texto  \
# 0  1 2 Créditos Edición de textos Sandr a Milena ...
# 1  1 2 Créditos Edición de textos Sandr a Milena ...
# 2  1 2 Créditos Edición de textos Sandr a Milena ...
# 3  1 2 Créditos Edición de textos Sandr a Milena ...
# 4  1 2 Créditos Edición de textos Sandr a Milena ...
#
#                                            preguntas  longitud_original  \
# 0  ¿Qué objetivo tienen los sistemas agroforestal...              21503
# 1  ¿Cuáles son las principales características ag...              21503
# 2  Según el documento, ¿qué porcentaje del área c...              21503
# 3  ¿En el sistema tradicional de explotación del ...              21503
# 4  ¿Cuál es la densidad de siembra promedio de ca...              21503
#
#    num_preguntas_generadas
# 0                       20
# 1                       20
# 2                       20
# 3                       20
# 4                       20

# %%
df_preguntas_libros.drop(['longitud_original','num_preguntas_generadas'],axis=1, inplace=True)

# %%
df_preguntas_libros.drop(['longitud_original','num_preguntas_generadas'],axis=1, inplace=True)
df_preguntas_revistas.drop(['longitud_original','num_preguntas_generadas'],axis=1, inplace=True)

# %%
df_preguntas_completo = pd.concat([df_preguntas_libros, df_preguntas_revistas, df_preguntas], 
                       ignore_index=True)

# %%
df_preguntas_completo.shape
# Out:
# (4635, 2)

# %%
df_preguntas_completo.to_csv("preguntas.csv")

# %%
df_preguntas_completo.head()
# Out:
#                                                texto  \
# 0  1 2 Créditos Edición de textos Sandr a Milena ...
# 1  1 2 Créditos Edición de textos Sandr a Milena ...
# 2  1 2 Créditos Edición de textos Sandr a Milena ...
# 3  1 2 Créditos Edición de textos Sandr a Milena ...
# 4  1 2 Créditos Edición de textos Sandr a Milena ...
#
#                                            preguntas
# 0  ¿Qué objetivo tienen los sistemas agroforestal...
# 1  ¿Cuáles son las principales características ag...
# 2  Según el documento, ¿qué porcentaje del área c...
# 3  ¿En el sistema tradicional de explotación del ...
# 4  ¿Cuál es la densidad de siembra promedio de ca...

# %%
def responder_preguntas(df_preguntas, modelo):
    
    respuestas = []
    
    for index, row in df_preguntas.iterrows():
        texto = row['texto']
        pregunta = row['preguntas']
        
        print(f"Procesando pregunta {index + 1}/{len(df_preguntas)}")
        
        system_prompt = """Eres un ingeniero agrónomo experto en café de Colombia. 
        Responde la pregunta de forma directa y precisa usando únicamente la información del texto.
        
        INSTRUCCIONES:
        - Da una respuesta directa sin mencionar "según el texto" o "el texto dice"
        - No incluyas referencias textuales ni citas
        - Respuesta concisa y técnica"""
        
        human_message = f"""Texto: {texto}

        Pregunta: {pregunta}

        Respuesta:"""
        
        messages = [
            SystemMessage(system_prompt),
            HumanMessage(human_message)
        ]
        
        respuesta = modelo.invoke(messages)
        
        if hasattr(respuesta, 'content'):
            contenido = respuesta.content
        else:
            contenido = str(respuesta)
        
        respuestas.append(contenido)

    df_preguntas['respuestas'] = respuestas
    
    return df_preguntas

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model2 = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    api_key=GOOGLE_API_KEY,
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(
    model="gpt-4.1-mini-2025-04-14",
    max_completion_tokens=800)

# %%
<#This script processes a DataFrame of texts and questions, using two language models to generate answers. It handles rate limits and saves progress incrementally.#>

import pandas as pd
from langchain_core.messages import HumanMessage, SystemMessage
from concurrent.futures import ThreadPoolExecutor, as_completed
import os
import time
import random

def procesar_pregunta(args):
    index, texto, pregunta, modelo, modelo2, total = args
    print(f"Procesando pregunta {index + 1}/{total}")
    
    system_prompt = """Eres un ingeniero agrónomo experto en café de Colombia. 
    Responde la pregunta de forma directa y precisa usando únicamente la información del texto.
    
    INSTRUCCIONES:
    - Dar respuestas técnicas y precisas
    - Da una respuesta directa sin mencionar "según el texto" o "el texto dice"
    - No incluyas referencias textuales ni citas
    - Respuesta concisa y técnica
    - Solo la información esencial"""
    
    human_message = f"""Texto: {texto}

Pregunta: {pregunta}

Respuesta:"""
    
    messages = [SystemMessage(system_prompt), HumanMessage(human_message)]
    
    for intento in range(3):
        try:
            if (index + 1) % 20 == 0:
                print(f"Pausa de 1 minuto después de {index + 1} preguntas...")
                time.sleep(60)
            
            respuesta = modelo.invoke(messages)
            if hasattr(respuesta, 'content'):
                contenido = respuesta.content
            else:
                contenido = str(respuesta)
            return index, contenido
            
        except Exception as e:
            if "rate_limit" in str(e).lower() or "429" in str(e):
                wait_time = (2 ** intento) + random.uniform(1, 3)
                print(f"Rate limit en pregunta {index + 1}, esperando {wait_time:.1f}s")
                time.sleep(wait_time)
            else:
                print(f"Error con modelo principal en pregunta {index + 1}, intentando fallback...")
                break

    for intento in range(3):
        try:
            respuesta = modelo2.invoke(messages)
            contenido = respuesta.content
            print(f"✓ Fallback Claude exitoso en pregunta {index + 1}")
            return index, contenido
            
        except Exception as e:
            if "rate_limit" in str(e).lower() or "429" in str(e):
                wait_time = (2 ** intento) + random.uniform(1, 3)
                print(f"Rate limit en Claude pregunta {index + 1}, esperando {wait_time:.1f}s")
                time.sleep(wait_time)
            else:
                print(f"Error con Claude en pregunta {index + 1}: {str(e)}")
                import traceback
                traceback.print_exc()
    
    return index, "[Error: Ambos modelos fallaron]"

def responder_preguntas(df_preguntas, modelo, modelo2):
    os.makedirs("questionsfocus", exist_ok=True)
    
    total = len(df_preguntas)
    args = [(i, row['texto'], row['preguntas'], modelo, modelo2, total) 
            for i, (_, row) in enumerate(df_preguntas.iterrows())]
    
    respuestas = [''] * total
    completadas = 0
    
    with ThreadPoolExecutor(max_workers=5) as executor:
        futures = {executor.submit(procesar_pregunta, arg): arg[0] for arg in args}
        
        for future in as_completed(futures):
            index, respuesta = future.result()
            respuestas[index] = respuesta
            completadas += 1
            
            if completadas % 100 == 0:
                df_temp = df_preguntas.copy()
                df_temp['respuestas'] = respuestas
                df_temp_completed = df_temp[df_temp['respuestas'] != '']
                batch_num = completadas // 100
                filename = f"questionsfocus/batch_{batch_num:03d}_parcial.csv"
                df_temp_completed.to_csv(filename, index=False)
                print(f"💾 Guardadas {completadas} respuestas en {filename}")
    
    df_resultado = df_preguntas.copy()
    df_resultado['respuestas'] = respuestas
    df_resultado.to_csv("questionsfocus/resultado_final.csv", index=False)
    print(f"💾 Guardado resultado final con {total} preguntas")
    
    return df_resultado

# %%
df_con_respuestas = responder_preguntas(df_preguntas_libros, model, model2)
# Out:
# Procesando pregunta 1/456
# Procesando pregunta 2/456
# Procesando pregunta 3/456
# Procesando pregunta 4/456
# Procesando pregunta 5/456
# Procesando pregunta 6/456
# Procesando pregunta 7/456
# Procesando pregunta 8/456
# Procesando pregunta 9/456
# Procesando pregunta 10/456
# Procesando pregunta 11/456
# Procesando pregunta 12/456
# Procesando pregunta 13/456
# Procesando pregunta 14/456
# Procesando pregunta 15/456
# Procesando pregunta 16/456
# Procesando pregunta 17/456
# Procesando pregunta 18/456
# Procesando pregunta 19/456
# Procesando pregunta 20/456
# Pausa de 1 minuto después de 20 preguntas...
# Procesando pregunta 21/456
# Procesando pregunta 22/456
# Procesando pregunta 23/456
# Procesando pregunta 24/456
# Procesando pregunta 25/456
# Procesando pregunta 26/456
# Procesando pregunta 27/456
# Procesando pregunta 28/456
# Procesando pregunta 29/456
# Procesando pregunta 30/456
# Procesando pregunta 31/456
# Procesando pregunta 32/456
# Procesando pregunta 33/456
# Procesando pregunta 34/456
# Procesando pregunta 35/456
# Procesando pregunta 36/456
# Procesando pregunta 37/456
# Procesando pregunta 38/456
# Procesando pregunta 39/456
# Procesando pregunta 40/456
# Pausa de 1 minuto después de 40 preguntas...
# Procesando pregunta 41/456
# Procesando pregunta 42/456
# Procesando pregunta 43/456
# Procesando pregunta 44/456
# Procesando pregunta 45/456
# Procesando pregunta 46/456
# Procesando pregunta 47/456
# Procesando pregunta 48/456
# Procesando pregunta 49/456
# Procesando pregunta 50/456
# Procesando pregunta 51/456
# Procesando pregunta 52/456
# Procesando pregunta 53/456
# Procesando pregunta 54/456
# Procesando pregunta 55/456
# Procesando pregunta 56/456
# Procesando pregunta 57/456
# Procesando pregunta 58/456
# Procesando pregunta 59/456
# Procesando pregunta 60/456
# Pausa de 1 minuto después de 160 preguntas...
# Procesando pregunta 161/456
# Procesando pregunta 162/456
# Procesando pregunta 163/456
# Procesando pregunta 164/456
# Procesando pregunta 165/456
# Procesando pregunta 166/456
# Procesando pregunta 167/456
# Procesando pregunta 168/456
# Procesando pregunta 169/456
# Procesando pregunta 170/456
# Procesando pregunta 171/456
# Procesando pregunta 172/456
# Procesando pregunta 173/456
# Procesando pregunta 174/456
# Procesando pregunta 175/456
# Procesando pregunta 176/456
# Procesando pregunta 177/456
# Procesando pregunta 178/456
# Procesando pregunta 179/456
# Procesando pregunta 180/456
# Pausa de 1 minuto después de 180 preguntas...
# Procesando pregunta 181/456
# Procesando pregunta 182/456
# Procesando pregunta 183/456
# Procesando pregunta 184/456
# Procesando pregunta 185/456
# Procesando pregunta 186/456
# Procesando pregunta 187/456
# Procesando pregunta 188/456
# Procesando pregunta 189/456
# Procesando pregunta 190/456
# Procesando pregunta 191/456
# Procesando pregunta 192/456
# Procesando pregunta 193/456
# Procesando pregunta 194/456
# Procesando pregunta 195/456
# Procesando pregunta 196/456
# Procesando pregunta 197/456
# Procesando pregunta 198/456
# Procesando pregunta 199/456
# Procesando pregunta 200/456
# Pausa de 1 minuto después de 200 preguntas...
# Procesando pregunta 201/456
# Procesando pregunta 202/456
# Procesando pregunta 203/456
# Procesando pregunta 204/456
# Procesando pregunta 205/456
# 💾 Guardadas 200 respuestas en questionsfocus/batch_002_parcial.csv
# Procesando pregunta 206/456
# Procesando pregunta 207/456
# Procesando pregunta 208/456
# Procesando pregunta 209/456
# Procesando pregunta 210/456
# Procesando pregunta 211/456
# Procesando pregunta 212/456
# Procesando pregunta 213/456
# Procesando pregunta 214/456
# Procesando pregunta 215/456
# Procesando pregunta 216/456
# Procesando pregunta 217/456
# Procesando pregunta 218/456
# Procesando pregunta 219/456
# Procesando pregunta 220/456
# Pausa de 1 minuto después de 220 preguntas...
# Procesando pregunta 221/456
# Procesando pregunta 222/456
# Procesando pregunta 223/456
# Procesando pregunta 224/456
# Procesando pregunta 225/456
# Procesando pregunta 226/456
# Procesando pregunta 227/456
# Procesando pregunta 228/456
# Procesando pregunta 229/456
# Procesando pregunta 230/456
# Procesando pregunta 231/456
# Procesando pregunta 232/456
# Procesando pregunta 233/456
# Procesando pregunta 234/456
# Procesando pregunta 235/456
# Procesando pregunta 236/456
# Procesando pregunta 237/456
# Procesando pregunta 238/456
# Procesando pregunta 239/456
# Procesando pregunta 240/456
# Pausa de 1 minuto después de 240 preguntas...
# Procesando pregunta 241/456
# Procesando pregunta 242/456
# Procesando pregunta 243/456
# Procesando pregunta 244/456
# Procesando pregunta 245/456
# Procesando pregunta 246/456
# Procesando pregunta 247/456
# Procesando pregunta 248/456
# Procesando pregunta 249/456
# Procesando pregunta 250/456
# Procesando pregunta 251/456
# Procesando pregunta 252/456
# Procesando pregunta 253/456
# Procesando pregunta 254/456
# Procesando pregunta 255/456
# Procesando pregunta 256/456
# Procesando pregunta 257/456
# Procesando pregunta 258/456
# Procesando pregunta 259/456
# Procesando pregunta 260/456
# Procesando pregunta 361/456
# Procesando pregunta 362/456
# Procesando pregunta 363/456
# Procesando pregunta 364/456
# Procesando pregunta 365/456
# Procesando pregunta 366/456
# Procesando pregunta 367/456
# Procesando pregunta 368/456
# Procesando pregunta 369/456
# Procesando pregunta 370/456
# Procesando pregunta 371/456
# Procesando pregunta 372/456
# Procesando pregunta 373/456
# Procesando pregunta 374/456
# Procesando pregunta 375/456
# Procesando pregunta 376/456
# Procesando pregunta 377/456
# Procesando pregunta 378/456
# Procesando pregunta 379/456
# Procesando pregunta 380/456
# Pausa de 1 minuto después de 380 preguntas...
# Procesando pregunta 381/456
# Procesando pregunta 382/456
# Procesando pregunta 383/456
# Procesando pregunta 384/456
# Procesando pregunta 385/456
# Procesando pregunta 386/456
# Procesando pregunta 387/456
# Procesando pregunta 388/456
# Procesando pregunta 389/456
# Procesando pregunta 390/456
# Procesando pregunta 391/456
# Procesando pregunta 392/456
# Procesando pregunta 393/456
# Procesando pregunta 394/456
# Procesando pregunta 395/456
# Procesando pregunta 396/456
# Procesando pregunta 397/456
# Procesando pregunta 398/456
# Procesando pregunta 399/456
# Procesando pregunta 400/456
# Pausa de 1 minuto después de 400 preguntas...
# Procesando pregunta 401/456
# Procesando pregunta 402/456
# Procesando pregunta 403/456
# Procesando pregunta 404/456
# Procesando pregunta 405/456
# 💾 Guardadas 400 respuestas en questionsfocus/batch_004_parcial.csv
# Procesando pregunta 406/456
# Procesando pregunta 407/456
# Procesando pregunta 408/456
# Procesando pregunta 409/456
# Procesando pregunta 410/456
# Procesando pregunta 411/456
# Procesando pregunta 412/456
# Procesando pregunta 413/456
# Procesando pregunta 414/456
# Procesando pregunta 415/456
# Procesando pregunta 416/456
# Procesando pregunta 417/456
# Procesando pregunta 418/456
# Procesando pregunta 419/456
# Procesando pregunta 420/456
# Pausa de 1 minuto después de 420 preguntas...
# Procesando pregunta 421/456
# Procesando pregunta 422/456
# Procesando pregunta 423/456
# Procesando pregunta 424/456
# Procesando pregunta 425/456
# Procesando pregunta 426/456
# Procesando pregunta 427/456
# Procesando pregunta 428/456
# Procesando pregunta 429/456
# Procesando pregunta 430/456
# Procesando pregunta 431/456
# Procesando pregunta 432/456
# Procesando pregunta 433/456
# Procesando pregunta 434/456
# Procesando pregunta 435/456
# Procesando pregunta 436/456
# Procesando pregunta 437/456
# Procesando pregunta 438/456
# Procesando pregunta 439/456
# Procesando pregunta 440/456
# Pausa de 1 minuto después de 440 preguntas...
# Procesando pregunta 441/456
# Procesando pregunta 442/456
# Procesando pregunta 443/456
# Procesando pregunta 444/456
# Procesando pregunta 445/456
# Procesando pregunta 446/456
# Procesando pregunta 447/456
# Procesando pregunta 448/456
# Procesando pregunta 449/456
# Procesando pregunta 450/456
# Procesando pregunta 451/456
# Procesando pregunta 452/456
# Procesando pregunta 453/456
# Procesando pregunta 454/456
# Procesando pregunta 455/456
# Procesando pregunta 456/456
# 💾 Guardado resultado final con 456 preguntas

# %%
df_preguntas_total = pd.read_csv("questions/resultado_final.csv")

# %%
df_preguntas_completo = pd.concat([df_preguntas_total,df_con_respuestas], 
                       ignore_index=True)

# %%
df_preguntas_completo.shape
# Out:
# (5091, 3)

# %%
df_preguntas_completo.to_csv("respuestas_finaltotal.csv")

# %%
df_con_respuestas.head()
# Out:
#                                                texto  \
# 0  1 2 Créditos Edición de textos Sandr a Milena ...
# 1  1 2 Créditos Edición de textos Sandr a Milena ...
# 2  1 2 Créditos Edición de textos Sandr a Milena ...
# 3  1 2 Créditos Edición de textos Sandr a Milena ...
# 4  1 2 Créditos Edición de textos Sandr a Milena ...
#
#                                            preguntas  \
# 0  ¿Qué objetivo tienen los sistemas agroforestal...
# 1  ¿Cuáles son las principales características ag...
# 2  Según el documento, ¿qué porcentaje del área c...
# 3  ¿En el sistema tradicional de explotación del ...
# 4  ¿Cuál es la densidad de siembra promedio de ca...
#
#                                           respuestas
# 0  Los sistemas agroforestales cafeteros tienen c...
# 1  Las principales características agronómicas de...
# 2  El 33,1% del área cafetera en Colombia se encu...
# 3  Las variedades principales empleadas bajo somb...
# 4  La densidad de siembra promedio de cafetos por...

# %%
def test_preguntas_cafe_sin_texto():
    NUM_PREGUNTAS = 10
    
    system_prompt = f"""Eres un ingeniero agrónomo y caficultor colombiano experto en café. 
Tu tarea es generar exactamente {NUM_PREGUNTAS} preguntas técnicas importantes sobre café que un especialista en café debería conocer.

CRITERIOS para las preguntas:
- Deben ser preguntas técnicas específicas del sector cafetero
- Enfoque en aspectos agronómicos, fitosanitarios, de calidad y procesamiento
- Usar terminología técnica precisa del sector cafetero
- Cubrir diferentes áreas: producción, cultivo, procesamiento, variedades, enfermedades, plagas, calidad, postcosecha, beneficio
- Evitar preguntas muy genéricas o básicas
- Preguntas que un caficultor profesional encuentre relevantes y útiles

ÁREAS TÉCNICAS A INCLUIR:
- Aspectos agronómicos: densidades de siembra, manejo de suelos, nutrición, podas
- Fitosanidad: enfermedades, plagas, síntomas, tratamientos, resistencia
- Variedades: características varietales, resistencias, adaptaciones climáticas
- Procesamiento: métodos de beneficio, fermentación, secado, despulpado
- Calidad: atributos sensoriales, defectos, parámetros físicos, taza
- Postcosecha: almacenamiento, trilla, clasificación

FORMATO REQUERIDO:
1. [Primera pregunta técnica]
2. [Segunda pregunta técnica]
...
{NUM_PREGUNTAS}. [Última pregunta técnica]"""

    human_message = "Genera las preguntas técnicas de café más importantes que un especialista debería conocer."

    messages = [
        SystemMessage(system_prompt),
        HumanMessage(human_message)
    ]
    
    try:
        print("🤖 Sending request to the model...")

        respuesta = model.invoke(messages)

        if hasattr(respuesta, 'content'):
            contenido = respuesta.content
        else:
            contenido = str(respuesta)
        
        print("\n📋 MODEL RESPONSE:")
        print("-" * 50)
        print(contenido)
        print("-" * 50)
        
        lineas = contenido.split('\n')
        preguntas = []
        
        for linea in lineas:
            linea = linea.strip()
            if linea and any(linea.startswith(f"{i}.") for i in range(1, NUM_PREGUNTAS + 1)):
                pregunta = linea
                for i in range(1, NUM_PREGUNTAS + 1):
                    if pregunta.startswith(f"{i}."):
                        pregunta = pregunta[len(f"{i}."):].strip()
                        break
                if len(pregunta) > 10:
                    preguntas.append(pregunta)
        
        print(f"\n✅ PREGUNTAS EXTRAÍDAS ({len(preguntas)}):")
        print("=" * 60)
        
        for i, pregunta in enumerate(preguntas, 1):
            print(f"{i:2d}. {pregunta}")
        
        print(f"\n📊 SUMMARY:")
        print(f"- Questions generated: {len(preguntas)}")
        print(f"- Type: Técnicas generales de café")
        print(f"- Not based document")
        
        return preguntas
        
    except Exception as e:
        print(f"❌ Error: {str(e)}")
        return None

# %%
preguntas_generales = test_preguntas_cafe_sin_texto()
# Out:
# 🤖 Enviando solicitud al modelo...
#
# 📋 RESPUESTA DEL MODELO:
# --------------------------------------------------
# 1. ¿Cuál es la densidad óptima de siembra para Coffea arabica en sistemas de producción de alta productividad, considerando el manejo de sombra y topografía en zonas cafeteras colombianas?
#
# 2. ¿Cómo influye el manejo nutricional integral, con énfasis en relaciones C/N y aplicación foliar de micronutrientes, en el desarrollo vegetativo y la calidad de la taza en café?
#
# 3. ¿Cuáles son los principales signos visuales y métodos de diagnóstico temprano de la roya del café (Hemileia vastatrix) y cuál es el protocolo recomendado para su manejo integrado, incluyendo variedades resistentes y aplicaciones fitosanitarias?
#
# 4. ¿Qué criterios fisiológicos y productivos se emplean para seleccionar la entrada y la frecuencia de podas de renovación y formación en cafetales, y cómo impactan en la longevidad y productividad de la plantación?
#
# 5. ¿Cuáles son las características agronómicas, productivas y de calidad de taza diferenciadas entre las variedades Castillo, Cenicafé 1 y Geisha, y en qué condiciones climáticas y altitudinales presentan su máximo potencial productivo?
#
# 6. ¿Cuáles son los métodos de control biológico y químico más efectivos para el manejo integrado de la broca del café (Hypothenemus hampei), y cómo se deben implementar estrategias de muestreo técnico para determinar umbrales de intervención?
#
# 7. ¿Cómo incide el manejo y determinación del punto óptimo de fermentación en procesos de beneficio húmedo sobre el desarrollo de atributos sensoriales, concentración de ácidos orgánicos y defectos en la taza?
#
# 8. ¿Qué parámetros técnicos y logísticos deben considerarse para un secado adecuado del café pergamino, a fin de garantizar un contenido de humedad entre 10% y 12%, minimizando riesgos de desarrollo de mohos y ocratoxinas?
#
# 9. ¿Cuáles son los defectos más frecuentes observables en café verde durante el proceso de trilla y clasificación, cómo afectan los parámetros de exportación y cuáles son las herramientas para su detección y eliminación?
#
# 10. ¿Qué prácticas óptimas de almacenamiento postcosecha se recomiendan para preservar la calidad física y sensorial del café, evitando la absorción de olores, deterioro físico y la contaminación cruzada en bodegas especializadas?
# --------------------------------------------------
#
# ✅ PREGUNTAS EXTRAÍDAS (10):
# ============================================================
#  1. ¿Cuál es la densidad óptima de siembra para Coffea arabica en sistemas de producción de alta productividad, considerando el manejo de sombra y topografía en zonas cafeteras colombianas?
#  2. ¿Cómo influye el manejo nutricional integral, con énfasis en relaciones C/N y aplicación foliar de micronutrientes, en el desarrollo vegetativo y la calidad de la taza en café?
#  3. ¿Cuáles son los principales signos visuales y métodos de diagnóstico temprano de la roya del café (Hemileia vastatrix) y cuál es el protocolo recomendado para su manejo integrado, incluyendo variedades resistentes y aplicaciones fitosanitarias?
#  4. ¿Qué criterios fisiológicos y productivos se emplean para seleccionar la entrada y la frecuencia de podas de renovación y formación en cafetales, y cómo impactan en la longevidad y productividad de la plantación?
#  5. ¿Cuáles son las características agronómicas, productivas y de calidad de taza diferenciadas entre las variedades Castillo, Cenicafé 1 y Geisha, y en qué condiciones climáticas y altitudinales presentan su máximo potencial productivo?
#  6. ¿Cuáles son los métodos de control biológico y químico más efectivos para el manejo integrado de la broca del café (Hypothenemus hampei), y cómo se deben implementar estrategias de muestreo técnico para determinar umbrales de intervención?
#  7. ¿Cómo incide el manejo y determinación del punto óptimo de fermentación en procesos de beneficio húmedo sobre el desarrollo de atributos sensoriales, concentración de ácidos orgánicos y defectos en la taza?
#  8. ¿Qué parámetros técnicos y logísticos deben considerarse para un secado adecuado del café pergamino, a fin de garantizar un contenido de humedad entre 10% y 12%, minimizando riesgos de desarrollo de mohos y ocratoxinas?
#  9. ¿Cuáles son los defectos más frecuentes observables en café verde durante el proceso de trilla y clasificación, cómo afectan los parámetros de exportación y cuáles son las herramientas para su detección y eliminación?
# 10. ¿Qué prácticas óptimas de almacenamiento postcosecha se recomiendan para preservar la calidad física y sensorial del café, evitando la absorción de olores, deterioro físico y la contaminación cruzada en bodegas especializadas?
#
# 📊 RESUMEN:
# - Preguntas generadas: 10
# - Tipo: Técnicas generales de café
# - Sin documento base

# %%
preguntas_generales
# Out:
# ['¿Cuál es la densidad óptima de siembra para Coffea arabica en sistemas de producción de alta productividad, considerando el manejo de sombra y topografía en zonas cafeteras colombianas?',
#  '¿Cómo influye el manejo nutricional integral, con énfasis en relaciones C/N y aplicación foliar de micronutrientes, en el desarrollo vegetativo y la calidad de la taza en café?',
#  '¿Cuáles son los principales signos visuales y métodos de diagnóstico temprano de la roya del café (Hemileia vastatrix) y cuál es el protocolo recomendado para su manejo integrado, incluyendo variedades resistentes y aplicaciones fitosanitarias?',
#  '¿Qué criterios fisiológicos y productivos se emplean para seleccionar la entrada y la frecuencia de podas de renovación y formación en cafetales, y cómo impactan en la longevidad y productividad de la plantación?',
#  '¿Cuáles son las características agronómicas, productivas y de calidad de taza diferenciadas entre las variedades Castillo, Cenicafé 1 y Geisha, y en qué condiciones climáticas y altitudinales presentan su máximo potencial productivo?',
#  '¿Cuáles son los métodos de control biológico y químico más efectivos para el manejo integrado de la broca del café (Hypothenemus hampei), y cómo se deben implementar estrategias de muestreo técnico para determinar umbrales de intervención?',
#  '¿Cómo incide el manejo y determinación del punto óptimo de fermentación en procesos de beneficio húmedo sobre el desarrollo de atributos sensoriales, concentración de ácidos orgánicos y defectos en la taza?',
#  '¿Qué parámetros técnicos y logísticos deben considerarse para un secado adecuado del café pergamino, a fin de garantizar un contenido de humedad entre 10% y 12%, minimizando riesgos de desarrollo de mohos y ocratoxinas?',
#  '¿Cuáles son los defectos más frecuentes observables en café verde durante el proceso de trilla y clasificación, cómo afectan los parámetros de exportación y cuáles son las herramientas para su detección y eliminación?',
#  '¿Qué prácticas óptimas de almacenamiento postcosecha se recomiendan para preservar la calidad física y sensorial del café, evitando la absorción de olores, deterioro físico y la contaminación cruzada en bodegas especializadas?']
